# %%
from datetime import datetime

min_lat, max_lat = 20, 30
min_lon, max_lon = -82, -97
bbox = [min_lon, min_lat, max_lon, max_lat]
crs = "urn:ogc:def:crs:OGC:1.3:CRS84"

# Temporal range of 1 week.
start = datetime(2017, 4, 14, 0, 0, 0)
stop = datetime(2017, 4, 21, 0, 0, 0)

# Sea surface temperature CF names.
cf_names = ["sea_water_temperature",
            "sea_surface_temperature",
            "sea_water_potential_temperature",
            "equivalent_potential_temperature",
            "sea_water_conservative_temperature",
            "pseudo_equivalent_potential_temperature"]

# %%
def fes_date_filter(start, stop, constraint="overlaps"):
    from owslib import fes
    start = start.strftime("%Y-%m-%d %H:00")
    stop = stop.strftime("%Y-%m-%d %H:00")
    if constraint == "overlaps":
        propertyname = "apiso:TempExtent_begin"
        begin = fes.PropertyIsLessThanOrEqualTo(propertyname=propertyname,
                                                literal=stop)
        propertyname = "apiso:TempExtent_end"
        end = fes.PropertyIsGreaterThanOrEqualTo(propertyname=propertyname,
                                                 literal=start)
    elif constraint == "within":
        propertyname = "apiso:TempExtent_begin"
        begin = fes.PropertyIsGreaterThanOrEqualTo(propertyname=propertyname,
                                                   literal=start)
        propertyname = "apiso:TempExtent_end"
        end = fes.PropertyIsLessThanOrEqualTo(propertyname=propertyname,
                                              literal=stop)
    else:
        raise NameError("Unrecognized constraint {}".format(constraint))
    return begin, end

# %%
from owslib import fes

kw = dict(
    wildCard="*",
    escapeChar="\\",
    singleChar="?",
    propertyname="apiso:AnyText"
)

or_filt = fes.Or(
    [fes.PropertyIsLike(literal=("*%s*" % val), **kw)
        for val in cf_names])

begin, end = fes_date_filter(start, stop)
bbox_crs = fes.BBox(bbox, crs=crs)

filter_list = [
    fes.And(
        [
            bbox_crs,
            begin, end,
            or_filt,
            fes.Not([fes.PropertyIsLike(literal="*cdip*", **kw)]),
        ]
    )
]

# %%
def get_csw_records(csw, filter_list, pagesize=10, maxrecords=1000):
    """Iterate `maxrecords`/`pagesize` times until the requested value in
    `maxrecords` is reached.
    """
    from owslib.fes import SortBy, SortProperty
    # Iterate over sorted results.
    sortby = SortBy([SortProperty("dc:title", "ASC")])
    csw_records = {}
    startposition = 0
    nextrecord = getattr(csw, "results", 1)
    while nextrecord != 0:
        csw.getrecords2(constraints=filter_list, startposition=startposition,
                        maxrecords=pagesize, sortby=sortby)
        csw_records.update(csw.records)
        if csw.results["nextrecord"] == 0:
            break
        startposition += pagesize + 1  # Last one is included.
        if startposition >= maxrecords:
            break
    csw.records.update(csw_records)

# %%
from owslib.csw import CatalogueServiceWeb


endpoint = "https://data.ioos.us/csw"

csw = CatalogueServiceWeb(endpoint, timeout=60)

get_csw_records(csw, filter_list, pagesize=10, maxrecords=1000)

records = "\n".join(csw.records.keys())
print("Found {} records.\n".format(len(csw.records.keys())))
# Out:
# Found 178 records.

# %%
for key, value in list(csw.records.items()):
    print(u"[{}]\n{}\n".format(value.title, key))
# Out:
# [urn:ioos:station:NOAA.NOS.CO-OPS:t03010 station, Port Manatee]
# opendap.co-ops.nos.noaa.gov-urn_ioos_station_NOAA.NOS.CO-OPS_t03010
#
# [VENF1 - Venice, FL]
# wmo_venf1
#
# [Venice, FL]
# sdf.ndbc.noaa.gov-urn_ioos_station_wmo_venf1
#
# [VENICE INLET AT CROW'S NEST MARINA AT VENICE FL]
# gov_usgs_waterdata_02299735
#
# [WACCASASSA RIVER NR GULF HAMMOCK, FLA.]
# gov_usgs_waterdata_02313700
#
# [WEST GULF - 207 NM East of Brownsville, TX]
# sdf.ndbc.noaa.gov-urn_ioos_station_wmo_42002
#
# [WEST TAMPA  - 112 NM WNW of Tampa, FL]
# sdf.ndbc.noaa.gov-urn_ioos_station_wmo_42036
#
# [WITHLACOOCHEE R AT CHAMBERS IS NEAR YANKEETOWN FL]
# gov_usgs_waterdata_02313272
#
# [42003 - East GULF - 208 NM West of Naples, FL]
# wmo_42003
#
# [42013 - C10 - WFS Central Buoy, 25m Isobath - sea_water_temperature]
# edu.usf.marine.comps:c10:sea_water_temperature
#
# [42022 - C12 - WFS Central Buoy, 50m Isobath - sea_water_temperature]
# edu.usf.marine.comps:c12:sea_water_temperature
#
# [* 42023 - C13 - WFS South Buoy, 50m Isobath]
# edu_usf_marine_comps_c13
#
# [42023 - C13 - WFS South Buoy, 50m Isobath - sea_water_temperature]
# edu.usf.marine.comps:c13:sea_water_temperature
#
# [42036 - WEST TAMPA - 112 NM WNW of Tampa, FL]
# wmo_42036
#
# [42039 - PENSACOLA - 115NM ESE of Pensacola, FL]
# wmo_42039
#
# [42098 - Egmont Channel Entrance, FL - 214]
# gtbmac_ports_42098
#
# [8770475 - Port Arthur, TX]
# sdf.ndbc.noaa.gov-urn_ioos_station_wmo_port2
#
# [8770733 - Lynchburg Landing, TX]
# sdf.ndbc.noaa.gov-urn_ioos_station_wmo_lybt2
#
# [8770777 - Manchester, TX]
# sdf.ndbc.noaa.gov-urn_ioos_station_wmo_ncht2
#
# [8770808 - High Island, TX]
# sdf.ndbc.noaa.gov-urn_ioos_station_wmo_hist2
#
# [8770971 - Rollover Pass, TX]
# sdf.ndbc.noaa.gov-urn_ioos_station_wmo_rlot2
#
# [8771486 - Galveston RR Bridge, TX]
# sdf.ndbc.noaa.gov-urn_ioos_station_wmo_grrt2
#
# [8771972 - San Luis Pass, TX]
# sdf.ndbc.noaa.gov-urn_ioos_station_wmo_luit2
#
# [8772985 - Sargent, TX]
# sdf.ndbc.noaa.gov-urn_ioos_station_wmo_sgnt2
#
# [8773037 - Seadrift, TX]
# sdf.ndbc.noaa.gov-urn_ioos_station_wmo_sdrt2
#
# [8773146 - Matagorda City, TX]
# sdf.ndbc.noaa.gov-urn_ioos_station_wmo_emat2
#
# [8773259 - Port Lavaca, TX]
# sdf.ndbc.noaa.gov-urn_ioos_station_wmo_vcat2
#
# [8773701 - Port O'Connor, Matagorda Bay, TX]
# sdf.ndbc.noaa.gov-urn_ioos_station_wmo_pcnt2
#
# [ALAFIA RIVER AT BELL SHOALS NEAR RIVERVIEW FL]
# gov_usgs_waterdata_02301638
#
# [ALAFIA RIVER AT GIBSONTON FL]
# gov_usgs_waterdata_02301721
#
# [ALAFIA RIVER AT LITHIA FL]
# gov_usgs_waterdata_02301500
#
# [ALAFIA RIVER AT RIVERVIEW FL]
# gov_usgs_waterdata_02301718
#
# [Apalachicola, FL]
# noaa_nos_co_ops_8728690
#
# [APALACHICOLA RIVER NR SUMATRA,FLA.]
# gov_usgs_waterdata_02359170
#
# [APK - Aripeka, FL]
# sdf.ndbc.noaa.gov-urn_ioos_station_wmo_arpf1
#
# [Aqua MODIS: 2012-2017 Daily Means]
# edu.ncsu.meas.oomg:secoora_modis_2012_2017
#
# [Auger - Garden Banks 426]
# sdf.ndbc.noaa.gov-urn_ioos_station_wmo_42361
#
# [AVHRR Sea Surface Temperature for MARACOOS (Mid-Atlantic Regional Association Coastal Ocean Observing System)]
# org.maracoos:AVHRR.2017.Unmasked.Agg
#
# [AVHRR Sea Surface Temperature for MARACOOS (Mid-Atlantic Regional Association Coastal Ocean Observing System)]
# org.maracoos:AVHRR.2017.1Agg
#
# [AVHRR Sea Surface Temperature for MARACOOS (Mid-Atlantic Regional Association Coastal Ocean Observing System)]
# org.maracoos:AVHRR.2017.7Agg
#
# [AVHRR Sea Surface Temperature for MARACOOS (Mid-Atlantic Regional Association Coastal Ocean Observing System)]
# org.maracoos:AVHRR.2017.3Agg
#
# [BAY OF CAMPECHE - 214 NM NE of Veracruz, MX]
# sdf.ndbc.noaa.gov-urn_ioos_station_wmo_42055
#
# [BLUE HOLE SPRING NR HILDRETH, FL]
# gov_usgs_waterdata_02322688
#
# [BW Pioneer buoy - C16471 - Walker Ridge 249]
# sdf.ndbc.noaa.gov-urn_ioos_station_wmo_42360
#
# [C10 - WFS Central Buoy, 25m Isobath]
# sdf.ndbc.noaa.gov-urn_ioos_station_wmo_42013
#
# [C12 - WFS Central Buoy, 50m Isobath]
# sdf.ndbc.noaa.gov-urn_ioos_station_wmo_42022
#
# [C13 - WFS South Buoy, 50m Isobath]
# sdf.ndbc.noaa.gov-urn_ioos_station_wmo_42023
#
# [Cedar Key, FL]
# sdf.ndbc.noaa.gov-urn_ioos_station_wmo_cdrf1
#
# [CHASSAHOWITZKA R AT DOG ISL NR CHASSAHOWITZKA FL]
# gov_usgs_waterdata_02310673
#
# [CHASSAHOWITZKA R AT MOUTH NR CHASSAHOWITZKA FL]
# gov_usgs_waterdata_02310674
#
# [CHASSAHOWITZKA RIVER NEAR CHASSAHOWITZKA FL]
# gov_usgs_waterdata_02310663
#
# [CHASSAHOWITZKA RIVER NEAR HOMOSASSA FL]
# gov_usgs_waterdata_02310650
#
# [Clam Bayou, FL]
# sdf.ndbc.noaa.gov-urn_ioos_station_wmo_clbf1
#
# [Clam Bayou - sea_water_temperature]
# edu.usf.marine.comps:clb:sea_water_temperature
#
# [Clearwater Beach, FL]
# noaa_nos_co_ops_8726724
#
# [CORPUS CHRISTI, TX - 60NM SSE of Corpus Christi, TX]
# sdf.ndbc.noaa.gov-urn_ioos_station_wmo_42020
#
# [Coupled Northwest Atlantic Prediction System (CNAPS)]
# edu.ncsu.meas:cnaps
#
# [CRYSTAL RIVER AT BAGLEY COVE NEAR CRYSTAL RIVER FL]
# gov_usgs_waterdata_02310747
#
# [CRYSTAL RV AT MOUTH NR SHELL ISL NR CRYSTAL RV FL]
# gov_usgs_waterdata_285531082412600
#
# [CURRY CREEK AT HIGHWAY 41 AT NOKOMIS FL]
# gov_usgs_waterdata_02299734
#
# [Daily MUR SST, Interim near-real-time (nrt) product]
# org.ghrsst:MURSST.2017.Agg
#
# [* Dry Bar, Apalachicola Bay]
# gov_fl_fldep_8728744
#
# [Dry Bar, Apalachicola Bay - sea_water_temperature]
# gov.fl.fldep:8728744:sea_water_temperature
#
# [* East Bay]
# gov_fl_fldep_8728603
#
# [East GULF - 208 NM West of Naples, FL]
# sdf.ndbc.noaa.gov-urn_ioos_station_wmo_42003
#
# [Egmont Channel Entrance, FL (214)]
# sdf.ndbc.noaa.gov-urn_ioos_station_wmo_42098
#
# [FANNING SPRINGS NR WILCOX FLA]
# gov_usgs_waterdata_02323502
#
# [FHP - Fred Howard Park, FL]
# sdf.ndbc.noaa.gov-urn_ioos_station_wmo_fhpf1
#
# [G1SST, 1km blended SST]
# G1_SST_GLOBAL
#
# [GALVESTON,TX -  22 NM East of Galveston, TX]
# sdf.ndbc.noaa.gov-urn_ioos_station_wmo_42035
#
# [Garden Key, FL]
# sdf.ndbc.noaa.gov-urn_ioos_station_wmo_gkyf1
#
# [GERG Flower Gardens Buoy V]
# sdf.ndbc.noaa.gov-urn_ioos_station_wmo_42047
#
# [GKYF1 - Garden Key, FL]
# gov_nps_ever_gkyf1
#
# [Global SST & Sea Ice Analysis, L4 OSTIA, 0.05 deg daily (METOFFICE-GLO-SST-L4-NRT-OBS-SST-V2)]
# AOOS_OSTIA
#
# [Grand Isle Blocks, LA / CSI09]
# sdf.ndbc.noaa.gov-urn_ioos_station_wmo_grbl1
#
# [HALLS RIVER AT HOMOSASSA SPRINGS FL]
# gov_usgs_waterdata_02310689
#
# [HALLS RIVER NEAR HOMOSASSA FL]
# gov_usgs_waterdata_02310690
#
# [HILLSBOROUGH R AT FOWLER AV NEAR TEMPLE TERRACE FL]
# gov_usgs_waterdata_02304000
#
# [HILLSBOROUGH RIVER AT PLATT STREET AT TAMPA FL]
# gov_usgs_waterdata_02306028
#
# [HILLSBOROUGH RIVER AT ROWLETT PK DR NEAR TAMPA FL]
# gov_usgs_waterdata_02304510
#
# [HOMOSASSA R AT HOMOSASSA FL]
# gov_usgs_waterdata_02310700
#
# [HOMOSASSA RIVER AT SHELL ISLAND NEAR HOMOSASSA FL]
# gov_usgs_waterdata_02310712
#
# [HOMOSASSA SPRINGS AT HOMOSASSA SPRINGS FL]
# gov_usgs_waterdata_02310678
#
# [Horn Mountain SPAR - Mississippi Canyon 126 and 127]
# sdf.ndbc.noaa.gov-urn_ioos_station_wmo_42374
#
# [ICHETUCKNEE R @ HWY27 NR HILDRETH, FL]
# gov_usgs_waterdata_02322700
#
# [Keaton Beach, FL]
# sdf.ndbc.noaa.gov-urn_ioos_station_wmo_ktnf1
#
# [Little St. Marks River - sea_water_temperature]
# gov.fl.fldep:8728703:sea_water_temperature
#
# [Louisiana Offshore Oil Port, LA]
# sdf.ndbc.noaa.gov-urn_ioos_station_wmo_lopl1
#
# [MANATEE RIVER AT RYE FL]
# gov_usgs_waterdata_023000095
#
# [MANATEE SPRING NR CHIEFLAND FLA]
# gov_usgs_waterdata_02323566
#
# [Marsh Island, LA / CSI03]
# sdf.ndbc.noaa.gov-urn_ioos_station_wmo_mrsl1
#
# [Mars - Mississippi Canyon 807]
# sdf.ndbc.noaa.gov-urn_ioos_station_wmo_42363
#
# [Mckay Bay Entrance, FL]
# noaa_nos_co_ops_8726667
#
# [MID GULF - 180 nm South of Southwest Pass, LA]
# sdf.ndbc.noaa.gov-urn_ioos_station_wmo_42001
#
# [mote-genie-20170404T1922]
# org.mote:mote-genie-20170404T1922_f070_8f49_1646
#
# [mote-genie-20170404T1922]
# mote-genie-20170404T1922
#
# [Na Kika FPU - Mississippi Canyon 474]
# sdf.ndbc.noaa.gov-urn_ioos_station_wmo_42375
#
# [NDBC Standard Meteorological Buoy Data, 1970-present]
# cwwcNDBCMet
#
# [Offshore St. Petersburg, FL (144)]
# sdf.ndbc.noaa.gov-urn_ioos_station_wmo_42099
#
# [Old Port Tampa, FL]
# noaa_nos_co_ops_8726607
#
# [OPTF1 - Tide Gauge Station]
# osmc_optf1
#
# [PEACE RIVER AT PLATT FL]
# gov_usgs_waterdata_02297345
#
# [PEACE RIVER NR PEACE RIVER HEIGHTS NR FT. OGDEN FL]
# gov_usgs_waterdata_02297350
#
# [PENSACOLA - 115NM SSE of Pensacola, FL]
# sdf.ndbc.noaa.gov-urn_ioos_station_wmo_42039
#
# [Perdido - Alaminos Canyon 857]
# sdf.ndbc.noaa.gov-urn_ioos_station_wmo_42390
#
# [Pilot's Cove, Apalachicola Bay - sea_water_temperature]
# gov.fl.fldep:8728732:sea_water_temperature
#
# [PITHLACHASCOTEE R AT MAIN ST AT NEW PORT RICHEY FL]
# gov_usgs_waterdata_02310308
#
# [PMAF1 - Tide Gauge Station]
# osmc_pmaf1
#
# [Pulaski Shoals Light, FL]
# sdf.ndbc.noaa.gov-urn_ioos_station_wmo_plsf1
#
# [Pulley Ridge, FL (226)]
# sdf.ndbc.noaa.gov-urn_ioos_station_wmo_42097
#
# [Ram Powell TLP - Viosca Knoll 956]
# sdf.ndbc.noaa.gov-urn_ioos_station_wmo_42364
#
# [Sabine Pass, TX]
# sdf.ndbc.noaa.gov-urn_ioos_station_wmo_srst2
#
# [SALT RIVER NEAR CRYSTAL RIVER FL]
# gov_usgs_waterdata_02310752
#
# [SANTA FE RIVER AT RIVER RISE NR HIGH SPRINGS, FL]
# gov_usgs_waterdata_02321958
#
# [SANTA FE RIVER AT WORTHINGTON SPRINGS, FLA.]
# gov_usgs_waterdata_02321500
#
# [SANTA FE RIVER NEAR FORT WHITE, FLA.]
# gov_usgs_waterdata_02322500
#
# [SANTA FE RIVER NR HILDRETH FLA]
# gov_usgs_waterdata_02322800
#
# [SARAGASSA CANAL AT CRYSTAL RIVER FL]
# gov_usgs_waterdata_02310740
#
# [Shell Alcyone Buoy - C16522 - Walker Ridge 552]
# sdf.ndbc.noaa.gov-urn_ioos_station_wmo_42395
#
# [Shell West Delta 143]
# sdf.ndbc.noaa.gov-urn_ioos_station_wmo_wdel1
#
# [South Atlantic Bight and Gulf of Mexico (SABGOM)]
# edu.ncsu.meas:sabgom
#
# [South Timbalier Block 52, LA / CSI06]
# sdf.ndbc.noaa.gov-urn_ioos_station_wmo_spll1
#
# [Southwest Pass, LA]
# sdf.ndbc.noaa.gov-urn_ioos_station_wmo_burl1
#
# [Stommel-20170120T2144]
# Stommel-20170120T2144
#
# [Stommel-20170120T2144]
# edu.tamu.gerg:Stommel-20170120T2144_f070_8f49_1646
#
# [St Petersburg, FL]
# noaa_nos_co_ops_8726520
#
# [SULPHUR SPRINGS AT SULPHUR SPRINGS FL]
# gov_usgs_waterdata_02306000
#
# [SULPHUR SPRINGS RUN AT SULPHUR SPRINGS FL]
# gov_usgs_waterdata_023060003
#
# [SUWANNEE RIVER AT BRANFORD, FLA.]
# gov_usgs_waterdata_02320500
#
# [TABS D]
# sdf.ndbc.noaa.gov-urn_ioos_station_wmo_42048
#
# [TABS F]
# sdf.ndbc.noaa.gov-urn_ioos_station_wmo_42050
#
# [TABS R]
# sdf.ndbc.noaa.gov-urn_ioos_station_wmo_42051
#
# [TABS W]
# sdf.ndbc.noaa.gov-urn_ioos_station_wmo_42049
#
# [TGLO TABS Buoy B]
# sdf.ndbc.noaa.gov-urn_ioos_station_wmo_42043
#
# [TGLO TABS Buoy K]
# sdf.ndbc.noaa.gov-urn_ioos_station_wmo_42045
#
# [Thunder Horse Semisub - Mississippi Canyon 778]
# sdf.ndbc.noaa.gov-urn_ioos_station_wmo_42887
#
# [Tyndall AFB Tower C (N4), FL]
# sdf.ndbc.noaa.gov-urn_ioos_station_wmo_sgof1
#
# [UNH Appledore Island CO2]
# UNH_WBD
#
# [urn:ioos:station:NOAA.NOS.CO-OPS:8726520 station, St. Petersburg, Tampa Bay, FL]
# opendap.co-ops.nos.noaa.gov-urn_ioos_station_NOAA.NOS.CO-OPS_8726520
#
# [urn:ioos:station:NOAA.NOS.CO-OPS:8726607 station, Old Port Tampa, FL]
# opendap.co-ops.nos.noaa.gov-urn_ioos_station_NOAA.NOS.CO-OPS_8726607
#
# [urn:ioos:station:NOAA.NOS.CO-OPS:8726667 station, Mckay Bay Entrance, FL]
# opendap.co-ops.nos.noaa.gov-urn_ioos_station_NOAA.NOS.CO-OPS_8726667
#
# [urn:ioos:station:NOAA.NOS.CO-OPS:8726724 station, Clearwater Beach, FL]
# opendap.co-ops.nos.noaa.gov-urn_ioos_station_NOAA.NOS.CO-OPS_8726724
#
# [urn:ioos:station:NOAA.NOS.CO-OPS:8727520 station, Cedar Key, FL]
# opendap.co-ops.nos.noaa.gov-urn_ioos_station_NOAA.NOS.CO-OPS_8727520
#
# [urn:ioos:station:NOAA.NOS.CO-OPS:8728690 station, Apalachicola, FL]
# opendap.co-ops.nos.noaa.gov-urn_ioos_station_NOAA.NOS.CO-OPS_8728690
#
# [urn:ioos:station:NOAA.NOS.CO-OPS:8760721 station, Pilottown, LA]
# opendap.co-ops.nos.noaa.gov-urn_ioos_station_NOAA.NOS.CO-OPS_8760721
#
# [urn:ioos:station:NOAA.NOS.CO-OPS:8760922 station, Pilots Station East, S.W. Pass, LA]
# opendap.co-ops.nos.noaa.gov-urn_ioos_station_NOAA.NOS.CO-OPS_8760922
#
# [urn:ioos:station:NOAA.NOS.CO-OPS:8761305 station, Shell Beach, LA]
# opendap.co-ops.nos.noaa.gov-urn_ioos_station_NOAA.NOS.CO-OPS_8761305
#
# [urn:ioos:station:NOAA.NOS.CO-OPS:8761724 station, Grand Isle, LA]
# opendap.co-ops.nos.noaa.gov-urn_ioos_station_NOAA.NOS.CO-OPS_8761724
#
# [urn:ioos:station:NOAA.NOS.CO-OPS:8762075 station, Port Fourchon, Belle Pass, LA]
# opendap.co-ops.nos.noaa.gov-urn_ioos_station_NOAA.NOS.CO-OPS_8762075
#
# [urn:ioos:station:NOAA.NOS.CO-OPS:8762482 station, West Bank 1, Bayou Gauche, LA]
# opendap.co-ops.nos.noaa.gov-urn_ioos_station_NOAA.NOS.CO-OPS_8762482
#
# [urn:ioos:station:NOAA.NOS.CO-OPS:8764044 station, Berwick, Atchafalaya River, LA]
# opendap.co-ops.nos.noaa.gov-urn_ioos_station_NOAA.NOS.CO-OPS_8764044
#
# [urn:ioos:station:NOAA.NOS.CO-OPS:8764227 station, LAWMA, Amerada Pass, LA]
# opendap.co-ops.nos.noaa.gov-urn_ioos_station_NOAA.NOS.CO-OPS_8764227
#
# [urn:ioos:station:NOAA.NOS.CO-OPS:8764314 station, Eugene Island, North of , Gulf of Mexico, LA]
# opendap.co-ops.nos.noaa.gov-urn_ioos_station_NOAA.NOS.CO-OPS_8764314
#
# [urn:ioos:station:NOAA.NOS.CO-OPS:8766072 station, Freshwater Canal Locks, LA]
# opendap.co-ops.nos.noaa.gov-urn_ioos_station_NOAA.NOS.CO-OPS_8766072
#
# [urn:ioos:station:NOAA.NOS.CO-OPS:8768094 station, Calcasieu Pass, LA]
# opendap.co-ops.nos.noaa.gov-urn_ioos_station_NOAA.NOS.CO-OPS_8768094
#
# [urn:ioos:station:NOAA.NOS.CO-OPS:8770475 station, Port Arthur, TX]
# opendap.co-ops.nos.noaa.gov-urn_ioos_station_NOAA.NOS.CO-OPS_8770475
#
# [urn:ioos:station:NOAA.NOS.CO-OPS:8770520 station, Rainbow Bridge, TX]
# opendap.co-ops.nos.noaa.gov-urn_ioos_station_NOAA.NOS.CO-OPS_8770520
#
# [urn:ioos:station:NOAA.NOS.CO-OPS:8770570 station, Sabine Pass North, TX]
# opendap.co-ops.nos.noaa.gov-urn_ioos_station_NOAA.NOS.CO-OPS_8770570
#
# [urn:ioos:station:NOAA.NOS.CO-OPS:8770733 station, Lynchburg Landing, TX]
# opendap.co-ops.nos.noaa.gov-urn_ioos_station_NOAA.NOS.CO-OPS_8770733
#
# [urn:ioos:station:NOAA.NOS.CO-OPS:8770777 station, Manchester, TX]
# opendap.co-ops.nos.noaa.gov-urn_ioos_station_NOAA.NOS.CO-OPS_8770777
#
# [urn:ioos:station:NOAA.NOS.CO-OPS:8770808 station, High Island, TX]
# opendap.co-ops.nos.noaa.gov-urn_ioos_station_NOAA.NOS.CO-OPS_8770808
#
# [urn:ioos:station:NOAA.NOS.CO-OPS:8770822 station, Texas Point, Sabine Pass, TX]
# opendap.co-ops.nos.noaa.gov-urn_ioos_station_NOAA.NOS.CO-OPS_8770822
#
# [urn:ioos:station:NOAA.NOS.CO-OPS:8770971 station, Rollover Pass, TX]
# opendap.co-ops.nos.noaa.gov-urn_ioos_station_NOAA.NOS.CO-OPS_8770971
#
# [urn:ioos:station:NOAA.NOS.CO-OPS:8771013 station, Eagle Point, Galveston Bay, TX]
# opendap.co-ops.nos.noaa.gov-urn_ioos_station_NOAA.NOS.CO-OPS_8771013
#
# [urn:ioos:station:NOAA.NOS.CO-OPS:8771341 station, Galveston Bay Entrance, North Jetty]
# opendap.co-ops.nos.noaa.gov-urn_ioos_station_NOAA.NOS.CO-OPS_8771341
#
# [urn:ioos:station:NOAA.NOS.CO-OPS:8771450 station, Galveston Pier 21, TX]
# opendap.co-ops.nos.noaa.gov-urn_ioos_station_NOAA.NOS.CO-OPS_8771450
#
# [urn:ioos:station:NOAA.NOS.CO-OPS:8771486 station, Galveston Railroad Bridge, TX]
# opendap.co-ops.nos.noaa.gov-urn_ioos_station_NOAA.NOS.CO-OPS_8771486
#
# [urn:ioos:station:NOAA.NOS.CO-OPS:8771972 station, San Luis Pass, TX]
# opendap.co-ops.nos.noaa.gov-urn_ioos_station_NOAA.NOS.CO-OPS_8771972
#
# [urn:ioos:station:NOAA.NOS.CO-OPS:8772471 station, Freeport SPIP, Freeport Harbor, TX]
# opendap.co-ops.nos.noaa.gov-urn_ioos_station_NOAA.NOS.CO-OPS_8772471
#
# [urn:ioos:station:NOAA.NOS.CO-OPS:8772985 station, Sargent, TX]
# opendap.co-ops.nos.noaa.gov-urn_ioos_station_NOAA.NOS.CO-OPS_8772985
#
# [urn:ioos:station:NOAA.NOS.CO-OPS:8773037 station, Seadrift, TX]
# opendap.co-ops.nos.noaa.gov-urn_ioos_station_NOAA.NOS.CO-OPS_8773037
#
# [urn:ioos:station:NOAA.NOS.CO-OPS:8773146 station, Matagorda City, TX]
# opendap.co-ops.nos.noaa.gov-urn_ioos_station_NOAA.NOS.CO-OPS_8773146
#
# [urn:ioos:station:NOAA.NOS.CO-OPS:8773259 station, Port Lavaca, TX]
# opendap.co-ops.nos.noaa.gov-urn_ioos_station_NOAA.NOS.CO-OPS_8773259
#
# [urn:ioos:station:NOAA.NOS.CO-OPS:8773701 station, Port O'Connor, TX]
# opendap.co-ops.nos.noaa.gov-urn_ioos_station_NOAA.NOS.CO-OPS_8773701
#
# [urn:ioos:station:NOAA.NOS.CO-OPS:8773767 station, Matagorda Bay Entrance Channel, TX]
# opendap.co-ops.nos.noaa.gov-urn_ioos_station_NOAA.NOS.CO-OPS_8773767
#
# [urn:ioos:station:NOAA.NOS.CO-OPS:8774230 station, Aransas Wildlife Refuge, TX]
# opendap.co-ops.nos.noaa.gov-urn_ioos_station_NOAA.NOS.CO-OPS_8774230
#
# [urn:ioos:station:NOAA.NOS.CO-OPS:g08010 station, Fred Hartman Br., Houston Ship Channel]
# opendap.co-ops.nos.noaa.gov-urn_ioos_station_NOAA.NOS.CO-OPS_g08010
#
# [urn:ioos:station:NOAA.NOS.CO-OPS:mc0101 station, Atchafalaya Bar Channel]
# opendap.co-ops.nos.noaa.gov-urn_ioos_station_NOAA.NOS.CO-OPS_mc0101

# %%
import textwrap


key, value = list(csw.records.items())[-1]

print("\n".join(textwrap.wrap(value.abstract)))
# Out:
# NOAA.NOS.CO-OPS Sensor Observation Service (SOS) Server  This station
# provides the following variables: Direction of sea water velocity,
# Platform orientation, Platform pitch angle, Platform roll angle, Sea
# water speed, Sea water temperature

# %%
print("\n".join(value.subjects))
# Out:
# Air Temperature
# Barometric Pressure
# Conductivity
# Currents
# Datum
# Harmonic Constituents
# Rain Fall
# Relative Humidity
# Salinity
# Visibility
# Water Level
# Water Level Predictions
# Water Temperature
# Winds
# direction_of_sea_water_velocity
# platform_orientation
# platform_pitch_angle
# platform_roll_angle
# sea_water_speed
# sea_water_temperature
# climatologyMeteorologyAtmosphere

# %%
from geolinks import sniff_link

msg = "geolink: {geolink}\nscheme: {scheme}\nURL: {url}\n".format
for ref in value.references:
    print(msg(geolink=sniff_link(ref["url"]), **ref))
# Out:
# geolink: OGC:SOS
# scheme: Atchafalaya Bar Channel
# URL: https://opendap.co-ops.nos.noaa.gov/ioos-dif-sos/SOS?service=SOS&version=1.0.0&request=DescribeSensor&procedure=urn:ioos:station:NOAA.NOS.CO-OPS:mc0101&outputFormat=text/xml; subtype="sensorML/1.0.1/profiles/ioos_sos/1.0"
#
# geolink: OGC:SOS
# scheme: WWW:LINK - text/csv
# URL: http://opendap.co-ops.nos.noaa.gov/ioos-dif-sos/SOS?service=SOS&version=1.0.0&observedProperty=http://mmisw.org/ont/cf/parameter/direction_of_sea_water_velocity&offering=urn:ioos:station:NOAA.NOS.CO-OPS:mc0101&responseFormat=text/csv&request=GetObservation&eventTime=2019-10-14T16:10:23/2019-10-14T18:10:23
#
# geolink: OGC:SOS
# scheme: WWW:LINK - text/csv
# URL: http://opendap.co-ops.nos.noaa.gov/ioos-dif-sos/SOS?service=SOS&version=1.0.0&observedProperty=http://mmisw.org/ont/cf/parameter/platform_orientation&offering=urn:ioos:station:NOAA.NOS.CO-OPS:mc0101&responseFormat=text/csv&request=GetObservation&eventTime=2019-10-14T16:10:23/2019-10-14T18:10:23
#
# geolink: OGC:SOS
# scheme: WWW:LINK - text/csv
# URL: http://opendap.co-ops.nos.noaa.gov/ioos-dif-sos/SOS?service=SOS&version=1.0.0&observedProperty=http://mmisw.org/ont/cf/parameter/platform_pitch_angle&offering=urn:ioos:station:NOAA.NOS.CO-OPS:mc0101&responseFormat=text/csv&request=GetObservation&eventTime=2019-10-14T16:10:23/2019-10-14T18:10:23
#
# geolink: OGC:SOS
# scheme: WWW:LINK - text/csv
# URL: http://opendap.co-ops.nos.noaa.gov/ioos-dif-sos/SOS?service=SOS&version=1.0.0&observedProperty=http://mmisw.org/ont/cf/parameter/platform_roll_angle&offering=urn:ioos:station:NOAA.NOS.CO-OPS:mc0101&responseFormat=text/csv&request=GetObservation&eventTime=2019-10-14T16:10:23/2019-10-14T18:10:23
#
# geolink: OGC:SOS
# scheme: WWW:LINK - text/csv
# URL: http://opendap.co-ops.nos.noaa.gov/ioos-dif-sos/SOS?service=SOS&version=1.0.0&observedProperty=http://mmisw.org/ont/cf/parameter/sea_water_speed&offering=urn:ioos:station:NOAA.NOS.CO-OPS:mc0101&responseFormat=text/csv&request=GetObservation&eventTime=2019-10-14T16:10:23/2019-10-14T18:10:23
#
# geolink: OGC:SOS
# scheme: WWW:LINK - text/csv
# URL: http://opendap.co-ops.nos.noaa.gov/ioos-dif-sos/SOS?service=SOS&version=1.0.0&observedProperty=http://mmisw.org/ont/cf/parameter/sea_water_temperature&offering=urn:ioos:station:NOAA.NOS.CO-OPS:mc0101&responseFormat=text/csv&request=GetObservation&eventTime=2019-10-14T16:10:23/2019-10-14T18:10:23
#
# geolink: OPeNDAP:OPeNDAP
# scheme: WWW:LINK
# URL: https://opendap.co-ops.nos.noaa.gov/ioos-dif-sos/images/current_meter.jpg
#
# geolink: None
# scheme: WWW:LINK
# URL: https://tidesandcurrents.noaa.gov/publications/NOAA_Technical_Report_NOS_CO-OPS_030_QC_requirements_doc(revised)-11102004.pdf
#
# geolink: None
# scheme: WWW:LINK
# URL: https://tidesandcurrents.noaa.gov
#
# geolink: OGC:SOS
# scheme: OGC:SOS
# URL: http://opendap.co-ops.nos.noaa.gov/ioos-dif-sos/SOS?service=SOS&request=GetCapabilities&acceptVersions=1.0.0

# %%
fmt = (
    "http://opendap.co-ops.nos.noaa.gov/ioos-dif-sos/SOS?"
    "service=SOS&"
    "eventTime={0:%Y-%m-%dT00:00:00}/{1:%Y-%m-%dT00:00:00}&"
    "observedProperty=http://mmisw.org/ont/cf/parameter/sea_water_temperature&"
    "version=1.0.0&"
    f"request=GetObservation&offering=urn:ioos:station:NOAA.NOS.CO-OPS:8771450&"
    "responseFormat=text/csv"
)

url = fmt.format(start, stop)

# %%
import pandas as pd


df = pd.read_csv(
    url,
    index_col="date_time",
    parse_dates=True,
)
df.index = df.index.tz_convert(None)

# %%
# %matplotlib inline

import matplotlib.pyplot as plt


fig, ax = plt.subplots(figsize=(11, 2.75))
ax = df["sea_water_temperature (C)"].plot(ax=ax)
ax.set_xlabel("")
ax.set_ylabel(r"Sea water temperature ($^\circ$C)")
ax.set_title(value.title);
